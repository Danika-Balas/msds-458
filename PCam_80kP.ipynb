# %% [markdown]
# <a href="https://colab.research.google.com/github/Danika-Balas/msds-458/blob/master/PCam_80kP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction

# %% [markdown]
# Data is a modified version of the PCam dataset--duplicates have been removed. The goal is to classify the images as cancerous or non-cancerous. A positive label indicates that the center 32x32px region of a patch contains at least one pixel of tumor tissue. Tumor tissue in the outer region of the patch does not influence the label.
# https://www.kaggle.com/c/histopathologic-cancer-detection/data?select=train_labels.csv

# %% [markdown]
# ###Acknowledgements
# Code was adapted from the following sources:
#
# Deep Learning with Python by Francis Chollet
#
# https://www.kaggle.com/gomezp/complete-beginner-s-guide-eda-keras-lb-0-93
#
# https://www.kaggle.com/vbookshelf/cnn-how-to-use-160-000-images-without-crashing
#
# https://www.kaggle.com/artgor/simple-eda-and-model-in-pytorch

# %% [markdown]
# #Setup and Preprocessing

# %%
import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
#%matplotlib inline
#sns.set(style="whitegrid")

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, roc_auc_score

import os, random
from random import shuffle
import cv2 #image processing
from glob import glob #for easily finding matching filenames 
from tqdm import tqdm, tqdm_notebook, trange #progress bar
import gc #garbage collection, for saving RAM

import tensorflow as tf
from tensorflow import keras
keras.__version__
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# '2.3.0-tf'

# %%
from keras import metrics
from keras import models
from keras import layers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ##Upload data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Code executed once to unzip the files, then commented out:

# %%
# #unzip set of training files (smaller dataset to make sure it works)
# !unzip -uq "/content/drive/My Drive/MSDS 458/PCam/sampleTrain.zip" -d "/content/drive/My Drive/MSDS 458/PCam/unzipped/sampleTrain"

# %%
#Check whether sample files are readable
sample_names = os.listdir('/content/drive/My Drive/MSDS 458/PCam/unzipped/sampleTrain/sampleTrain')
print(f'{len(sample_names)} files in sample directory')
print(sample_names[:5])
# Out:
# 10 files in sample directory
# ['00a0ad1de2cdf805f02c524a985bca5bce1d1b5f.tif', '0a0a8bdf1d78af77dcc0b94aef6fb5c2f841a3c0.tif', '0a0a2e923bdedb11f270dcd3f11d0f001df98f00.tif', '0a0d1a09e5cf9fcc308ecdc210450aecd204d344.tif', '0a0b4604d66cecfe668e26383c22fafb74484eef.tif']

# %% [markdown]
# Started with 10,000 training files in order develop model
#
# Be sure to change path below when adding more files

# %%
# #unzip set of training files
# !unzip -uq "/content/drive/My Drive/MSDS 458/PCam/train80P.zip" -d "/content/drive/My Drive/MSDS 458/PCam/unzipped/train"

# %%
# drive.mount("/content/drive", force_remount=True)

# %%
#Check whether sample files are readable
train_names = os.listdir('/content/drive/My Drive/MSDS 458/PCam/unzipped/train/train80P')
print(f'{len(train_names)} files in training directory')
print(train_names[:5])
# Out:
# 80001 files in training directory
# ['6d1bb57c0606f05dbd75f90a8d9e21a57e1267e0.tif', '9c043ab2adadfeb758c71d21432fccd3e43565c0.tif', '9cc775713dd09351172a350871a547346af08027.tif', '1c1b9b8dc88097d7df41ca9a24111359fd44a57d.tif', '7e45df9e3833b03a4491ef04de755bb04623ab6d.tif']

# %% [markdown]
# Code below to unzip testing data. It has not been run yet it order to save space on Drive.

# %%
# #unzip set of testing files 
# !unzip -uq "/content/drive/My Drive/MSDS 458/PCam/test.zip" -d "/content/drive/My Drive/MSDS 458/PCam/unzipped/test"

# %%
# #Check whether sample files are readable
# test_names = os.listdir('/content/drive/My Drive/MSDS 458/PCam/unzipped/test')
# print(f'{len(test_names)} files in testing directory')
# print(test_names[:5])

# %% [markdown]
# ##Set paths

# %%
path = '/content/drive/My Drive/MSDS 458/PCam/unzipped/'
train_path = path+'train/train80P'
test_path =  path+'test/'
sample_path = path+'sampleTrain/sampleTrain'  #contains 10 images, simply for testing data can be read

# %% [markdown]
# ##Load labels and filenames

# %%
labels = pd.read_csv('/content/drive/My Drive/MSDS 458/PCam/train_labels.csv')

# %%
df = pd.DataFrame({'path': glob(os.path.join(train_path,'*.tif'))}) # load the filenames
df['id'] = df.path.map(lambda x: x.split('/')[9].split(".")[0]) # keep only the file names in 'id'
df.head()
# Out:
#                                                 path                                        id
# 0  /content/drive/My Drive/MSDS 458/PCam/unzipped...  6d1bb57c0606f05dbd75f90a8d9e21a57e1267e0
# 1  /content/drive/My Drive/MSDS 458/PCam/unzipped...  9c043ab2adadfeb758c71d21432fccd3e43565c0
# 2  /content/drive/My Drive/MSDS 458/PCam/unzipped...  9cc775713dd09351172a350871a547346af08027
# 3  /content/drive/My Drive/MSDS 458/PCam/unzipped...  1c1b9b8dc88097d7df41ca9a24111359fd44a57d
# 4  /content/drive/My Drive/MSDS 458/PCam/unzipped...  7e45df9e3833b03a4491ef04de755bb04623ab6d

# %%
df = df.merge(labels, on = "id") # merge labels and filepaths

# %%
df.head(5) # print the first five entries
# Out:
#                                                 path  ... label
# 0  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# 1  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     1
# 2  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# 3  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     1
# 4  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
#
# [5 rows x 3 columns]

# %%
print(df.count) #check total number of rows in dataframe
# Out:
# <bound method DataFrame.count of                                                     path  ... label
# 0      /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# 1      /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     1
# 2      /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# 3      /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     1
# 4      /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# ...                                                  ...  ...   ...
# 79995  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# 79996  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# 79997  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     0
# 79998  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     1
# 79999  /content/drive/My Drive/MSDS 458/PCam/unzipped...  ...     1
#
# [80000 rows x 3 columns]>

# %% [markdown]
# ##Load images

# %%
def load_data(N,df):
    """ This functions loads N images using the data df
    """
    # allocate a numpy array for the images (N, 96x96px, 3 channels, values 0 - 255)
    X = np.zeros([N,40,40,3],dtype=np.uint8) 
    #convert the labels to a numpy array too
    dfLabel=df['label']
    y = np.squeeze(dfLabel.to_numpy())[0:N]
    #read images one by one, tdqm notebook displays a progress bar
    for i, row in tqdm_notebook(df.iterrows(), total=N):
        if i == N:
            break
        X[i] = cv2.imread(row['path'])

    # Scale the data to [0,1] interval
    X = X.astype('float16')/255      #comment out to perform EDA steps
    return X,y

# %%
# Load some of the images
N=1000
X,y = load_data(N=N,df=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # Remove the CWD from sys.path while we load stuff.
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %% [markdown]
# ##EDA

# %% [markdown]
# View some sample images. Non-cancerous samples are labeled 0, and cancerous samples are labeled 1.

# %%
fig = plt.figure(figsize=(12, 4), dpi=100)
np.random.seed(777) #we can use the seed to get a different set of random images
for plotNr,idx in enumerate(np.random.randint(0,N,16)):
    ax = fig.add_subplot(2, 16//2, plotNr+1, xticks=[], yticks=[]) #add subplots
    plt.imshow(X[idx]) #plot image
    ax.set_title('Label: ' + str(y[idx])) #show the label corresponding to the image

# %% [markdown]
# Evaluate the distribution of the two classes

# %%
plt.figure(figsize=[8,4])
plt.bar([0,1], [(y==0).sum(), (y==1).sum()])
plt.axis()
plt.xticks([0,1],[f"Negative (N={(y==0).sum()})",f"Positive (N={(y==1).sum()})"],rotation=45)
#plt.xticks(rotation=45)
#plt.rc('xtick',labelsize=10)
plt.ylabel('Samples')
# Out:
# Text(0, 0.5, 'Samples')

# %%
print(f"{round((y==1).sum()/len(y)*100,2)}% of the samples are positive.") 
print(f"We need to clear the baseline of {round((y==0).sum()/len(y)*100,2)}%, which would be the accuracy if we predicted that all of the samples were non-cancerous.")
# Out:
# 39.9% of the samples are positive.
# We need to clear the baseline of 60.1%, which would be the accuracy if we predicted that all of the samples were non-cancerous.

# %% [markdown]
# ###To evaluate the classes individually

# %%
positive_samples = X[y == 1]
negative_samples = X[y == 0]

# %% [markdown]
# Look at the distribution of the pixels for each color channel

# %%
# nr_of_bins = 256 #each possible pixel value will get a bin in the following histograms
# fig,axs = plt.subplots(4,2,sharey=True,figsize=(8,8),dpi=150)

# #RGB channels
# axs[0,0].hist(positive_samples[:,:,:,0].flatten(),bins=nr_of_bins,density=True)
# axs[0,1].hist(negative_samples[:,:,:,0].flatten(),bins=nr_of_bins,density=True)
# axs[1,0].hist(positive_samples[:,:,:,1].flatten(),bins=nr_of_bins,density=True)
# axs[1,1].hist(negative_samples[:,:,:,1].flatten(),bins=nr_of_bins,density=True)
# axs[2,0].hist(positive_samples[:,:,:,2].flatten(),bins=nr_of_bins,density=True)
# axs[2,1].hist(negative_samples[:,:,:,2].flatten(),bins=nr_of_bins,density=True)

# #All channels
# axs[3,0].hist(positive_samples.flatten(),bins=nr_of_bins,density=True)
# axs[3,1].hist(negative_samples.flatten(),bins=nr_of_bins,density=True)

# #Set image labels
# axs[0,0].set_title("Positive samples (N =" + str(positive_samples.shape[0]) + ")");
# axs[0,1].set_title("Negative samples (N =" + str(negative_samples.shape[0]) + ")");
# axs[0,1].set_ylabel("Red",rotation='horizontal',labelpad=35,fontsize=12)
# axs[1,1].set_ylabel("Green",rotation='horizontal',labelpad=35,fontsize=12)
# axs[2,1].set_ylabel("Blue",rotation='horizontal',labelpad=35,fontsize=12)
# axs[3,1].set_ylabel("RGB",rotation='horizontal',labelpad=35,fontsize=12)
# for i in range(4):
#     axs[i,0].set_ylabel("Relative frequency")
# axs[3,0].set_xlabel("Pixel value")
# axs[3,1].set_xlabel("Pixel value")
# fig.tight_layout()

# %%
nr_of_bins = 64 #we use a bit fewer bins to get a smoother image
fig,axs = plt.subplots(1,2,sharey=True, sharex = True, figsize=(8,2),dpi=150)
axs[0].hist(np.mean(positive_samples,axis=(1,2,3)),bins=nr_of_bins,density=True);
axs[1].hist(np.mean(negative_samples,axis=(1,2,3)),bins=nr_of_bins,density=True);
axs[0].set_title("Mean brightness, positive samples");
axs[1].set_title("Mean brightness, negative samples");
axs[0].set_xlabel("Image mean brightness")
axs[1].set_xlabel("Image mean brightness")
axs[0].set_ylabel("Relative frequency")
axs[1].set_ylabel("Relative frequency");

# %%
#Clean up variables to free up RAM
#Collect garbage
positives_samples = None
negative_samples = None
gc.collect();

# %% [markdown]
# #Prepare data for modeling

# %%
#Load remainder of dataset
X = None
y = None
gc.collect();
N = df["path"].size # get the number of images in the training data set
X,y = load_data(N=N,df=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # Remove the CWD from sys.path while we load stuff.
# HBox(children=(FloatProgress(value=0.0, max=80000.0), HTML(value='')))

# %%
X[1]
# Out:
# array([[[0.847 , 0.6   , 0.7725],
#         [0.965 , 0.7373, 0.9253],
#         [0.549 , 0.3254, 0.541 ],
#         ...,
#         [0.5806, 0.2588, 0.396 ],
#         [0.6743, 0.3608, 0.498 ],
#         [0.7217, 0.4197, 0.5527]],
#
#        [[0.753 , 0.5293, 0.682 ],
#         [0.8354, 0.6235, 0.792 ],
#         [0.4941, 0.2783, 0.4707],
#         ...,
#         [0.686 , 0.3804, 0.541 ],
#         [0.392 , 0.1059, 0.2627],
#         [0.549 , 0.2705, 0.4275]],
#
#        [[0.949 , 0.7217, 0.859 ],
#         [0.9097, 0.702 , 0.855 ],
#         [0.604 , 0.396 , 0.569 ],
#         ...,
#         [0.8076, 0.5254, 0.71  ],
#         [0.851 , 0.5884, 0.7646],
#         [0.8276, 0.5728, 0.749 ]],
#
#        ...,
#
#        [[0.9688, 0.7334, 0.89  ],
#         [0.863 , 0.6274, 0.784 ],
#         [0.6704, 0.4275, 0.5845],
#         ...,
#         [0.7803, 0.51  , 0.655 ],
#         [0.8394, 0.5566, 0.7217],
#         [0.8037, 0.51  , 0.6904]],
#
#        [[0.8394, 0.608 , 0.757 ],
#         [0.6665, 0.4392, 0.5767],
#         [0.6904, 0.447 , 0.5884],
#         ...,
#         [0.745 , 0.4707, 0.6157],
#         [0.702 , 0.4038, 0.569 ],
#         [0.6235, 0.3137, 0.4863]],
#
#        [[0.933 , 0.6943, 0.8354],
#         [0.686 , 0.447 , 0.5806],
#         [0.796 , 0.5254, 0.6704],
#         ...,
#         [0.5215, 0.2235, 0.3843],
#         [0.651 , 0.3452, 0.506 ],
#         [0.5884, 0.2744, 0.443 ]]], dtype=float16)

# %% [markdown]
# ##Train test split

# %%
# Split into train and test (80/20)
from sklearn.model_selection import train_test_split
#not setting a random_state and not shuffling because samples are already shuffled and want to save RAM
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((64000, 40, 40, 3), (16000, 40, 40, 3), (64000,), (16000,))

# %%
X = None
y = None
gc.collect();

# %% [markdown]
# #Define callbacks for training/testing times

# %%
# Define callback to get total training time
import datetime

class TrainRuntimeCallback(keras.callbacks.Callback):

  def on_train_begin(self,logs={}):
    self.start = datetime.datetime.now()

  def on_train_end(self,logs={}):
    self.process_time = (datetime.datetime.now() - self.start).total_seconds()

# %%
# Define callback to get total test time
import datetime

class TestRuntimeCallback(keras.callbacks.Callback):

  def on_test_begin(self,logs={}):
    self.start = datetime.datetime.now()

  def on_test_end(self,logs={}):
    self.process_time = (datetime.datetime.now() - self.start).total_seconds()

# %% [markdown]
# #Experiment 1:DNN
# Establish a baseline

# %% [markdown]
# ##Build and compile the model

# %%
model = models.Sequential()

model.add(layers.Flatten(input_shape=(40, 40, 3)))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 4800)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               480100
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 480,201
# Trainable params: 480,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ##Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=15,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/15
# 54400/54400 [==============================] - 6s 109us/step - loss: 0.6762 - accuracy: 0.5960 - val_loss: 0.6472 - val_accuracy: 0.5880
# Epoch 2/15
# 54400/54400 [==============================] - 4s 77us/step - loss: 0.6370 - accuracy: 0.6090 - val_loss: 0.6479 - val_accuracy: 0.5907
# Epoch 3/15
# 54400/54400 [==============================] - 4s 75us/step - loss: 0.6326 - accuracy: 0.6185 - val_loss: 0.6354 - val_accuracy: 0.6108
# Epoch 4/15
# 54400/54400 [==============================] - 4s 71us/step - loss: 0.6278 - accuracy: 0.6287 - val_loss: 0.6305 - val_accuracy: 0.6154
# Epoch 5/15
# 54400/54400 [==============================] - 4s 73us/step - loss: 0.6234 - accuracy: 0.6364 - val_loss: 0.6181 - val_accuracy: 0.6682
# Epoch 6/15
# 54400/54400 [==============================] - 4s 74us/step - loss: 0.6164 - accuracy: 0.6513 - val_loss: 0.6239 - val_accuracy: 0.6089
# Epoch 7/15
# 54400/54400 [==============================] - 4s 72us/step - loss: 0.6117 - accuracy: 0.6671 - val_loss: 0.6125 - val_accuracy: 0.6747
# Epoch 8/15
# 54400/54400 [==============================] - 4s 74us/step - loss: 0.6102 - accuracy: 0.6715 - val_loss: 0.6108 - val_accuracy: 0.6615
# Epoch 9/15
# 54400/54400 [==============================] - 4s 72us/step - loss: 0.6047 - accuracy: 0.6769 - val_loss: 0.6039 - val_accuracy: 0.6923
# Epoch 10/15
# 54400/54400 [==============================] - 4s 72us/step - loss: 0.5990 - accuracy: 0.6825 - val_loss: 0.6037 - val_accuracy: 0.6771
# Epoch 11/15
# 54400/54400 [==============================] - 4s 71us/step - loss: 0.5939 - accuracy: 0.6898 - val_loss: 0.5965 - val_accuracy: 0.6822
# Epoch 12/15
# 54400/54400 [==============================] - 4s 72us/step - loss: 0.5936 - accuracy: 0.6854 - val_loss: 0.6048 - val_accuracy: 0.6534
# Epoch 13/15
# 54400/54400 [==============================] - 4s 71us/step - loss: 0.5907 - accuracy: 0.6919 - val_loss: 0.5894 - val_accuracy: 0.6851
# Epoch 14/15
# 54400/54400 [==============================] - 4s 72us/step - loss: 0.5875 - accuracy: 0.6916 - val_loss: 0.5868 - val_accuracy: 0.6915
# Epoch 15/15
# 54400/54400 [==============================] - 4s 72us/step - loss: 0.5865 - accuracy: 0.6897 - val_loss: 0.5890 - val_accuracy: 0.6793

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 61.349588

# %% [markdown]
# ##Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 2s 98us/step
# (0.5947167757749557, 0.6701250076293945)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 1.563415

# %% [markdown]
# ### Create a dataframe for the training and test statistics

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail()
# Out:
#     val_loss  val_accuracy      loss  accuracy
# 10  0.596526      0.682187  0.593864  0.689798
# 11  0.604832      0.653437  0.593610  0.685404
# 12  0.589358      0.685104  0.590741  0.691857
# 13  0.586798      0.691458  0.587518  0.691562
# 14  0.588970      0.679271  0.586518  0.689687

# %%
results_df = history_df.iloc[-1:].copy()
results_df.insert(0,'model','DNN (1 layer)') 
results_df['test_loss'] = test_loss #incorporate test results
results_df['test_accuracy'] = test_acc
results_df['train time'] = train_time    
results_df['test time'] = test_time     
results_df
# Out:
#             model  val_loss  val_accuracy  ...  test_accuracy  train time  test time
# 14  DNN (1 layer)   0.58897      0.679271  ...       0.670125   61.349588   1.563415
#
# [1 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss/accuracy for each training epoch side by side.

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #Experiment 2, second DNN

# %% [markdown]
# This model is the same as in Experiment 1, but with an additional hidden layer. First hidden layer has 200 nodes, second hidden layer has 100 nodes.

# %% [markdown]
# ##Build and compile the model

# %%
model = models.Sequential()

model.add(layers.Flatten(input_shape=(40, 40, 3)))
model.add(layers.Dense(200, activation='relu'))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 4800)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 200)               960200
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 980,401
# Trainable params: 980,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ##Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=20,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/20
# 54400/54400 [==============================] - 4s 82us/step - loss: 0.6623 - accuracy: 0.5896 - val_loss: 0.6482 - val_accuracy: 0.6027
# Epoch 2/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.6338 - accuracy: 0.6114 - val_loss: 0.6243 - val_accuracy: 0.6010
# Epoch 3/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.6296 - accuracy: 0.6238 - val_loss: 0.6203 - val_accuracy: 0.6720
# Epoch 4/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.6249 - accuracy: 0.6317 - val_loss: 0.6343 - val_accuracy: 0.7018
# Epoch 5/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.6208 - accuracy: 0.6413 - val_loss: 0.6154 - val_accuracy: 0.6391
# Epoch 6/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.6168 - accuracy: 0.6467 - val_loss: 0.6137 - val_accuracy: 0.6746
# Epoch 7/20
# 54400/54400 [==============================] - 4s 80us/step - loss: 0.6165 - accuracy: 0.6483 - val_loss: 0.6115 - val_accuracy: 0.6846
# Epoch 8/20
# 54400/54400 [==============================] - 4s 79us/step - loss: 0.6116 - accuracy: 0.6561 - val_loss: 0.6002 - val_accuracy: 0.6759
# Epoch 9/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.6091 - accuracy: 0.6612 - val_loss: 0.5975 - val_accuracy: 0.6982
# Epoch 10/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.6018 - accuracy: 0.6725 - val_loss: 0.5903 - val_accuracy: 0.7054
# Epoch 11/20
# 54400/54400 [==============================] - 4s 79us/step - loss: 0.5901 - accuracy: 0.6854 - val_loss: 0.5766 - val_accuracy: 0.6971
# Epoch 12/20
# 54400/54400 [==============================] - 4s 79us/step - loss: 0.5832 - accuracy: 0.6935 - val_loss: 0.5731 - val_accuracy: 0.6896
# Epoch 13/20
# 54400/54400 [==============================] - 4s 79us/step - loss: 0.5797 - accuracy: 0.6970 - val_loss: 0.5901 - val_accuracy: 0.6846
# Epoch 14/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.5729 - accuracy: 0.7039 - val_loss: 0.5753 - val_accuracy: 0.6903
# Epoch 15/20
# 54400/54400 [==============================] - 4s 79us/step - loss: 0.5703 - accuracy: 0.7025 - val_loss: 0.5696 - val_accuracy: 0.6859
# Epoch 16/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.5659 - accuracy: 0.7108 - val_loss: 0.5609 - val_accuracy: 0.7034
# Epoch 17/20
# 54400/54400 [==============================] - 4s 79us/step - loss: 0.5646 - accuracy: 0.7068 - val_loss: 0.5630 - val_accuracy: 0.7124
# Epoch 18/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.5626 - accuracy: 0.7122 - val_loss: 0.5710 - val_accuracy: 0.7093
# Epoch 19/20
# 54400/54400 [==============================] - 4s 78us/step - loss: 0.5592 - accuracy: 0.7144 - val_loss: 0.5859 - val_accuracy: 0.6845
# Epoch 20/20
# 54400/54400 [==============================] - 4s 80us/step - loss: 0.5601 - accuracy: 0.7097 - val_loss: 0.5672 - val_accuracy: 0.7093

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 85.752367

# %% [markdown]
# ##Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 2s 107us/step
# (0.571902273118496, 0.7123749852180481)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 1.706699

# %% [markdown]
# ###Add training and test statistics to results dataframe

# %%
history_dict = history.history
history_df=pd.DataFrame(history_dict)
df = history_df.iloc[-1:].copy()
df.insert(0,'model','DNN (2 layer dropout)') 
df['test_loss'] = test_loss 
df['test_accuracy'] = test_acc
df['train time'] = train_time     
df['test time'] = test_time   
df
# Out:
#                     model  val_loss  ...  train time  test time
# 19  DNN (2 layer dropout)   0.56719  ...   85.752367   1.706699
#
# [1 rows x 9 columns]

# %%
results_df=results_df.append(df,ignore_index=True)
results_df
# Out:
#                    model  val_loss  ...  train time  test time
# 0          DNN (1 layer)   0.58897  ...   61.349588   1.563415
# 1  DNN (2 layer dropout)   0.56719  ...   85.752367   1.706699
#
# [2 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #Experiment 3: CNN with 2 convolutional layers

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(40, 40, 3)))
model.add(layers.MaxPooling2D((2, 2)))
#model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
#model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
#model.add(layers.Dropout(0.2))

model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 38, 38, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               1048832
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,068,481
# Trainable params: 1,068,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ##Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=15,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/15
# 54400/54400 [==============================] - 10s 188us/step - loss: 0.5214 - accuracy: 0.7446 - val_loss: 0.4841 - val_accuracy: 0.7769
# Epoch 2/15
# 54400/54400 [==============================] - 6s 102us/step - loss: 0.4810 - accuracy: 0.7751 - val_loss: 0.4633 - val_accuracy: 0.7870
# Epoch 3/15
# 54400/54400 [==============================] - 5s 100us/step - loss: 0.4668 - accuracy: 0.7824 - val_loss: 0.4792 - val_accuracy: 0.7735
# Epoch 4/15
# 54400/54400 [==============================] - 5s 101us/step - loss: 0.4529 - accuracy: 0.7933 - val_loss: 0.4537 - val_accuracy: 0.7932
# Epoch 5/15
# 54400/54400 [==============================] - 5s 100us/step - loss: 0.4385 - accuracy: 0.8010 - val_loss: 0.4382 - val_accuracy: 0.8080
# Epoch 6/15
# 54400/54400 [==============================] - 5s 99us/step - loss: 0.4280 - accuracy: 0.8080 - val_loss: 0.4513 - val_accuracy: 0.7920
# Epoch 7/15
# 54400/54400 [==============================] - 6s 101us/step - loss: 0.4171 - accuracy: 0.8118 - val_loss: 0.4418 - val_accuracy: 0.8134
# Epoch 8/15
# 54400/54400 [==============================] - 5s 101us/step - loss: 0.4038 - accuracy: 0.8208 - val_loss: 0.4402 - val_accuracy: 0.8051
# Epoch 9/15
# 54400/54400 [==============================] - 5s 101us/step - loss: 0.3862 - accuracy: 0.8299 - val_loss: 0.4305 - val_accuracy: 0.8097
# Epoch 10/15
# 54400/54400 [==============================] - 5s 101us/step - loss: 0.3712 - accuracy: 0.8367 - val_loss: 0.4291 - val_accuracy: 0.8044
# Epoch 11/15
# 54400/54400 [==============================] - 5s 101us/step - loss: 0.3527 - accuracy: 0.8467 - val_loss: 0.4341 - val_accuracy: 0.8099
# Epoch 12/15
# 54400/54400 [==============================] - 5s 100us/step - loss: 0.3306 - accuracy: 0.8595 - val_loss: 0.4531 - val_accuracy: 0.8093
# Epoch 13/15
# 54400/54400 [==============================] - 6s 102us/step - loss: 0.3045 - accuracy: 0.8726 - val_loss: 0.4716 - val_accuracy: 0.7959
# Epoch 14/15
# 54400/54400 [==============================] - 5s 101us/step - loss: 0.2711 - accuracy: 0.8896 - val_loss: 0.4850 - val_accuracy: 0.7949
# Epoch 15/15
# 54400/54400 [==============================] - 6s 101us/step - loss: 0.2340 - accuracy: 0.9078 - val_loss: 0.5239 - val_accuracy: 0.7977

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 87.033493

# %% [markdown]
# ##Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 2s 115us/step
# (0.5357609395086765, 0.792062520980835)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 1.846106

# %% [markdown]
# ###Add training and test statistics to results dataframe

# %%
history_dict = history.history
history_df=pd.DataFrame(history_dict)
df = history_df.iloc[-1:].copy()
df.insert(0,'model','CNN (2 layers)') 
df['test_loss'] = test_loss 
df['test_accuracy'] = test_acc
df['train time'] = train_time     
df['test time'] = test_time   
df
# Out:
#              model  val_loss  ...  train time  test time
# 14  CNN (2 layers)  0.523904  ...   87.033493   1.846106
#
# [1 rows x 9 columns]

# %%
results_df=results_df.append(df,ignore_index=True)
results_df
# Out:
#                    model  val_loss  ...  train time  test time
# 0          DNN (1 layer)  0.588970  ...   61.349588   1.563415
# 1  DNN (2 layer dropout)  0.567190  ...   85.752367   1.706699
# 2         CNN (2 layers)  0.523904  ...   87.033493   1.846106
#
# [3 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #Experiment 4: CNN with 2 convolutional layers, dropout

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(40, 40, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.2))

model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 38, 38, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 19, 19, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               1048832
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 1,068,481
# Trainable params: 1,068,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ##Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=15,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/15
# 54400/54400 [==============================] - 6s 114us/step - loss: 0.5325 - accuracy: 0.7353 - val_loss: 0.4927 - val_accuracy: 0.7714
# Epoch 2/15
# 54400/54400 [==============================] - 6s 110us/step - loss: 0.4909 - accuracy: 0.7703 - val_loss: 0.4711 - val_accuracy: 0.7840
# Epoch 3/15
# 54400/54400 [==============================] - 6s 110us/step - loss: 0.4746 - accuracy: 0.7823 - val_loss: 0.4665 - val_accuracy: 0.7898
# Epoch 4/15
# 54400/54400 [==============================] - 6s 109us/step - loss: 0.4567 - accuracy: 0.7919 - val_loss: 0.4473 - val_accuracy: 0.7990
# Epoch 5/15
# 54400/54400 [==============================] - 6s 110us/step - loss: 0.4458 - accuracy: 0.7986 - val_loss: 0.4545 - val_accuracy: 0.7947
# Epoch 6/15
# 54400/54400 [==============================] - 6s 109us/step - loss: 0.4355 - accuracy: 0.8040 - val_loss: 0.4246 - val_accuracy: 0.8110
# Epoch 7/15
# 54400/54400 [==============================] - 6s 109us/step - loss: 0.4244 - accuracy: 0.8104 - val_loss: 0.4385 - val_accuracy: 0.8035
# Epoch 8/15
# 54400/54400 [==============================] - 6s 108us/step - loss: 0.4163 - accuracy: 0.8156 - val_loss: 0.4158 - val_accuracy: 0.8180
# Epoch 9/15
# 54400/54400 [==============================] - 6s 109us/step - loss: 0.4075 - accuracy: 0.8203 - val_loss: 0.4444 - val_accuracy: 0.8033
# Epoch 10/15
# 54400/54400 [==============================] - 6s 111us/step - loss: 0.4026 - accuracy: 0.8234 - val_loss: 0.4172 - val_accuracy: 0.8178
# Epoch 11/15
# 54400/54400 [==============================] - 6s 110us/step - loss: 0.3954 - accuracy: 0.8251 - val_loss: 0.4235 - val_accuracy: 0.8155
# Epoch 12/15
# 54400/54400 [==============================] - 6s 110us/step - loss: 0.3840 - accuracy: 0.8317 - val_loss: 0.4241 - val_accuracy: 0.8081
# Epoch 13/15
# 54400/54400 [==============================] - 6s 112us/step - loss: 0.3739 - accuracy: 0.8361 - val_loss: 0.4188 - val_accuracy: 0.8150
# Epoch 14/15
# 54400/54400 [==============================] - 6s 109us/step - loss: 0.3681 - accuracy: 0.8390 - val_loss: 0.4242 - val_accuracy: 0.8107
# Epoch 15/15
# 54400/54400 [==============================] - 6s 109us/step - loss: 0.3552 - accuracy: 0.8464 - val_loss: 0.4068 - val_accuracy: 0.8171

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 89.789792

# %% [markdown]
# ##Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 2s 120us/step
# (0.404930263876915, 0.8218749761581421)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 1.926839

# %% [markdown]
# ###Add training and test statistics to results dataframe

# %%
history_dict = history.history
history_df=pd.DataFrame(history_dict)
df = history_df.iloc[-1:].copy()
df.insert(0,'model','CNN (2 layers, D)') 
df['test_loss'] = test_loss 
df['test_accuracy'] = test_acc
df['train time'] = train_time     
df['test time'] = test_time   
df
# Out:
#                 model  val_loss  ...  train time  test time
# 14  CNN (2 layers, D)  0.406787  ...   89.789792   1.926839
#
# [1 rows x 9 columns]

# %%
results_df=results_df.append(df,ignore_index=True)
results_df
# Out:
#                    model  val_loss  ...  train time  test time
# 0          DNN (1 layer)  0.588970  ...   61.349588   1.563415
# 1  DNN (2 layer dropout)  0.567190  ...   85.752367   1.706699
# 2         CNN (2 layers)  0.523904  ...   87.033493   1.846106
# 3      CNN (2 layers, D)  0.406787  ...   89.789792   1.926839
#
# [4 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
#Export results dataframe

from google.colab import files

results_df.to_csv('PCam80k_pt.csv')
files.download('PCam80k_pt.csv')

# %% [markdown]
# #Pre-trained Network

# %% [markdown]
# ###Instantiate the model

# %% [markdown]
# Do not use dropout initially

# %%
from keras.applications import VGG16

conv_base = VGG16(weights = 'imagenet',
                     include_top = False,
                     input_shape = (40, 40, 3))

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))

model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 3s 0us/step
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 14,846,273
# Trainable params: 14,846,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Select which layers to freeze during training

# %%
# Freeze all but the last three convolutional layers
conv_base.trainable = True

set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ###Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=15,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/15
# 54400/54400 [==============================] - 17s 310us/step - loss: 0.4729 - accuracy: 0.7848 - val_loss: 0.4289 - val_accuracy: 0.8045
# Epoch 2/15
# 54400/54400 [==============================] - 16s 298us/step - loss: 0.4146 - accuracy: 0.8130 - val_loss: 0.4086 - val_accuracy: 0.8130
# Epoch 3/15
# 54400/54400 [==============================] - 16s 299us/step - loss: 0.3969 - accuracy: 0.8210 - val_loss: 0.3999 - val_accuracy: 0.8195
# Epoch 4/15
# 54400/54400 [==============================] - 16s 298us/step - loss: 0.3754 - accuracy: 0.8327 - val_loss: 0.4004 - val_accuracy: 0.8201
# Epoch 5/15
# 54400/54400 [==============================] - 16s 299us/step - loss: 0.3617 - accuracy: 0.8416 - val_loss: 0.4019 - val_accuracy: 0.8241
# Epoch 6/15
# 54400/54400 [==============================] - 16s 299us/step - loss: 0.3448 - accuracy: 0.8483 - val_loss: 0.4156 - val_accuracy: 0.8181
# Epoch 7/15
# 54400/54400 [==============================] - 16s 298us/step - loss: 0.3283 - accuracy: 0.8562 - val_loss: 0.4055 - val_accuracy: 0.8201
# Epoch 8/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.3080 - accuracy: 0.8665 - val_loss: 0.4276 - val_accuracy: 0.8186
# Epoch 9/15
# 54400/54400 [==============================] - 16s 299us/step - loss: 0.2911 - accuracy: 0.8739 - val_loss: 0.4466 - val_accuracy: 0.8160
# Epoch 10/15
# 54400/54400 [==============================] - 16s 298us/step - loss: 0.2733 - accuracy: 0.8816 - val_loss: 0.4449 - val_accuracy: 0.8161
# Epoch 11/15
# 54400/54400 [==============================] - 16s 299us/step - loss: 0.2566 - accuracy: 0.8896 - val_loss: 0.5189 - val_accuracy: 0.8116
# Epoch 12/15
# 54400/54400 [==============================] - 16s 299us/step - loss: 0.2408 - accuracy: 0.8982 - val_loss: 0.4780 - val_accuracy: 0.8130
# Epoch 13/15
# 54400/54400 [==============================] - 16s 298us/step - loss: 0.2264 - accuracy: 0.9039 - val_loss: 0.5712 - val_accuracy: 0.8114
# Epoch 14/15
# 54400/54400 [==============================] - 16s 299us/step - loss: 0.2064 - accuracy: 0.9126 - val_loss: 0.5893 - val_accuracy: 0.8020
# Epoch 15/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.1969 - accuracy: 0.9178 - val_loss: 0.6520 - val_accuracy: 0.8066

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 244.583603

# %% [markdown]
# ###Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 5s 308us/step
# (0.654116459608078, 0.8091874718666077)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 4.925948

# %% [markdown]
# ###Add training and test statistics to results dataframe

# %%
history_dict = history.history
history_df=pd.DataFrame(history_dict)
df = history_df.iloc[-1:].copy()
df.insert(0,'model','VGG16, 3 thawed') 
df['test_loss'] = test_loss 
df['test_accuracy'] = test_acc
df['train time'] = train_time     
df['test time'] = test_time   
df
# Out:
#               model  val_loss  ...  train time  test time
# 14  VGG16, 3 thawed  0.651987  ...  244.583603   4.925948
#
# [1 rows x 9 columns]

# %%
results_df=results_df.append(df,ignore_index=True)
results_df
# Out:
#                    model  val_loss  ...  train time  test time
# 0          DNN (1 layer)  0.588970  ...   61.349588   1.563415
# 1  DNN (2 layer dropout)  0.567190  ...   85.752367   1.706699
# 2         CNN (2 layers)  0.523904  ...   87.033493   1.846106
# 3      CNN (2 layers, D)  0.406787  ...   89.789792   1.926839
# 4        VGG16, 3 thawed  0.651987  ...  244.583603   4.925948
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ##VGG16 with Dropout

# %%
conv_base = VGG16(weights = 'imagenet',
                     include_top = False,
                     input_shape = (40, 40, 3))

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 14,846,273
# Trainable params: 14,846,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Select which layers to freeze during training

# %%
# Freeze all but the last three convolutional layers
conv_base.trainable = True

set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ###Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=15,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/15
# 54400/54400 [==============================] - 17s 308us/step - loss: 0.4684 - accuracy: 0.7848 - val_loss: 0.4452 - val_accuracy: 0.8075
# Epoch 2/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.4151 - accuracy: 0.8137 - val_loss: 0.4083 - val_accuracy: 0.8146
# Epoch 3/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.3941 - accuracy: 0.8232 - val_loss: 0.4000 - val_accuracy: 0.8156
# Epoch 4/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.3801 - accuracy: 0.8329 - val_loss: 0.4239 - val_accuracy: 0.8017
# Epoch 5/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.3631 - accuracy: 0.8389 - val_loss: 0.4036 - val_accuracy: 0.8183
# Epoch 6/15
# 54400/54400 [==============================] - 16s 301us/step - loss: 0.3479 - accuracy: 0.8480 - val_loss: 0.4056 - val_accuracy: 0.8177
# Epoch 7/15
# 54400/54400 [==============================] - 16s 301us/step - loss: 0.3336 - accuracy: 0.8554 - val_loss: 0.4282 - val_accuracy: 0.8077
# Epoch 8/15
# 54400/54400 [==============================] - 16s 303us/step - loss: 0.3168 - accuracy: 0.8642 - val_loss: 0.4064 - val_accuracy: 0.8218
# Epoch 9/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.2993 - accuracy: 0.8718 - val_loss: 0.4219 - val_accuracy: 0.8204
# Epoch 10/15
# 54400/54400 [==============================] - 16s 301us/step - loss: 0.2833 - accuracy: 0.8796 - val_loss: 0.4739 - val_accuracy: 0.8150
# Epoch 11/15
# 54400/54400 [==============================] - 17s 304us/step - loss: 0.2679 - accuracy: 0.8863 - val_loss: 0.4811 - val_accuracy: 0.8129
# Epoch 12/15
# 54400/54400 [==============================] - 16s 301us/step - loss: 0.2510 - accuracy: 0.8933 - val_loss: 0.5380 - val_accuracy: 0.8152
# Epoch 13/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.2371 - accuracy: 0.9014 - val_loss: 0.5411 - val_accuracy: 0.8120
# Epoch 14/15
# 54400/54400 [==============================] - 16s 302us/step - loss: 0.2210 - accuracy: 0.9087 - val_loss: 0.5293 - val_accuracy: 0.8126
# Epoch 15/15
# 54400/54400 [==============================] - 16s 300us/step - loss: 0.2092 - accuracy: 0.9121 - val_loss: 0.5876 - val_accuracy: 0.8037

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 246.64825

# %% [markdown]
# ###Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 5s 304us/step
# (0.5839428730905056, 0.8073750138282776)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 4.863041

# %% [markdown]
# ###Add training and test statistics to results dataframe

# %%
history_dict = history.history
history_df=pd.DataFrame(history_dict)
df = history_df.iloc[-1:].copy()
df.insert(0,'model','VGG16, 3 thawed, D') 
df['test_loss'] = test_loss 
df['test_accuracy'] = test_acc
df['train time'] = train_time     
df['test time'] = test_time   
df
# Out:
#                  model  val_loss  ...  train time  test time
# 14  VGG16, 3 thawed, D  0.587627  ...   246.64825   4.863041
#
# [1 rows x 9 columns]

# %%
results_df=results_df.append(df,ignore_index=True)
results_df
# Out:
#                    model  val_loss  ...  train time  test time
# 0          DNN (1 layer)  0.588970  ...   61.349588   1.563415
# 1  DNN (2 layer dropout)  0.567190  ...   85.752367   1.706699
# 2         CNN (2 layers)  0.523904  ...   87.033493   1.846106
# 3      CNN (2 layers, D)  0.406787  ...   89.789792   1.926839
# 4        VGG16, 3 thawed  0.651987  ...  244.583603   4.925948
# 5     VGG16, 3 thawed, D  0.587627  ...  246.648250   4.863041
#
# [6 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ##VGG16 unfreeze 6 convolutional layers (block 4 and block 5)

# %%
conv_base = VGG16(weights = 'imagenet',
                     include_top = False,
                     input_shape = (40, 40, 3))

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
#model.add(layers.Dropout(0.3))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 14,846,273
# Trainable params: 14,846,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Select which layers to freeze during training

# %%
# Freeze all but the last three convolutional layers
conv_base.trainable = True

set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'block4_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ###Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=15,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/15
# 54400/54400 [==============================] - 22s 407us/step - loss: 0.4863 - accuracy: 0.7767 - val_loss: 0.4988 - val_accuracy: 0.7557
# Epoch 2/15
# 54400/54400 [==============================] - 22s 398us/step - loss: 0.4218 - accuracy: 0.8118 - val_loss: 0.4002 - val_accuracy: 0.8185
# Epoch 3/15
# 54400/54400 [==============================] - 22s 398us/step - loss: 0.4020 - accuracy: 0.8209 - val_loss: 0.3885 - val_accuracy: 0.8260
# Epoch 4/15
# 54400/54400 [==============================] - 22s 398us/step - loss: 0.4022 - accuracy: 0.8216 - val_loss: 0.3962 - val_accuracy: 0.8196
# Epoch 5/15
# 54400/54400 [==============================] - 22s 398us/step - loss: 0.3877 - accuracy: 0.8284 - val_loss: 0.4211 - val_accuracy: 0.8107
# Epoch 6/15
# 54400/54400 [==============================] - 22s 399us/step - loss: 0.3793 - accuracy: 0.8337 - val_loss: 0.3817 - val_accuracy: 0.8324
# Epoch 7/15
# 54400/54400 [==============================] - 22s 399us/step - loss: 0.3753 - accuracy: 0.8355 - val_loss: 0.3771 - val_accuracy: 0.8332
# Epoch 8/15
# 54400/54400 [==============================] - 22s 398us/step - loss: 0.3685 - accuracy: 0.8388 - val_loss: 0.3802 - val_accuracy: 0.8329
# Epoch 9/15
# 54400/54400 [==============================] - 22s 400us/step - loss: 0.3639 - accuracy: 0.8411 - val_loss: 0.4056 - val_accuracy: 0.8209
# Epoch 10/15
# 54400/54400 [==============================] - 22s 398us/step - loss: 0.3580 - accuracy: 0.8429 - val_loss: 0.3920 - val_accuracy: 0.8290
# Epoch 11/15
# 54400/54400 [==============================] - 22s 399us/step - loss: 0.3531 - accuracy: 0.8477 - val_loss: 0.3781 - val_accuracy: 0.8339
# Epoch 12/15
# 54400/54400 [==============================] - 22s 399us/step - loss: 0.3451 - accuracy: 0.8524 - val_loss: 0.4051 - val_accuracy: 0.8274
# Epoch 13/15
# 54400/54400 [==============================] - 22s 398us/step - loss: 0.3419 - accuracy: 0.8515 - val_loss: 0.3914 - val_accuracy: 0.8304
# Epoch 14/15
# 54400/54400 [==============================] - 22s 400us/step - loss: 0.3323 - accuracy: 0.8568 - val_loss: 0.3780 - val_accuracy: 0.8352
# Epoch 15/15
# 54400/54400 [==============================] - 22s 396us/step - loss: 0.3266 - accuracy: 0.8597 - val_loss: 0.4019 - val_accuracy: 0.8243

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 325.624062

# %% [markdown]
# ###Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 5s 299us/step
# (0.40796295475959776, 0.8156874775886536)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 4.787108

# %% [markdown]
# ###Add training and test statistics to results dataframe

# %%
history_dict = history.history
history_df=pd.DataFrame(history_dict)
df = history_df.iloc[-1:].copy()
df.insert(0,'model','VGG16, 6') 
df['test_loss'] = test_loss 
df['test_accuracy'] = test_acc
df['train time'] = train_time     
df['test time'] = test_time   
df
# Out:
#        model  val_loss  val_accuracy  ...  test_accuracy  train time  test time
# 14  VGG16, 6  0.401944      0.824271  ...       0.815687  325.624062   4.787108
#
# [1 rows x 9 columns]

# %%
results_df=results_df.append(df,ignore_index=True)
results_df
# Out:
#                    model  val_loss  ...  train time  test time
# 0          DNN (1 layer)  0.588970  ...   61.349588   1.563415
# 1  DNN (2 layer dropout)  0.567190  ...   85.752367   1.706699
# 2         CNN (2 layers)  0.523904  ...   87.033493   1.846106
# 3      CNN (2 layers, D)  0.406787  ...   89.789792   1.926839
# 4        VGG16, 3 thawed  0.651987  ...  244.583603   4.925948
# 5     VGG16, 3 thawed, D  0.587627  ...  246.648250   4.863041
# 6               VGG16, 6  0.401944  ...  325.624062   4.787108
#
# [7 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ##VGG16 unfreeze 6 convolutional layers (block 4 and block 5) with Dropout

# %%
conv_base = VGG16(weights = 'imagenet',
                     include_top = False,
                     input_shape = (40, 40, 3))

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 14,846,273
# Trainable params: 14,846,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Select which layers to freeze during training

# %%
# Freeze all but the last three convolutional layers
conv_base.trainable = True

set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'block4_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
model.compile(loss='binary_crossentropy', 
                   optimizer='adam',  
                   metrics=['accuracy'])

# %% [markdown]
# ###Train the model

# %%
train_rt = TrainRuntimeCallback()
history = model.fit(X_train, 
                    y_train,
                    callbacks=[train_rt],
                    epochs=15,
                    batch_size = 100,
                    validation_split = 0.15)
# Out:
# Train on 54400 samples, validate on 9600 samples
# Epoch 1/15
# 54400/54400 [==============================] - 22s 411us/step - loss: 0.4991 - accuracy: 0.7719 - val_loss: 0.4336 - val_accuracy: 0.8149
# Epoch 2/15
# 54400/54400 [==============================] - 22s 403us/step - loss: 0.4181 - accuracy: 0.8147 - val_loss: 0.4058 - val_accuracy: 0.8166
# Epoch 3/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.3983 - accuracy: 0.8250 - val_loss: 0.3816 - val_accuracy: 0.8314
# Epoch 4/15
# 54400/54400 [==============================] - 22s 406us/step - loss: 0.3806 - accuracy: 0.8340 - val_loss: 0.3858 - val_accuracy: 0.8238
# Epoch 5/15
# 54400/54400 [==============================] - 22s 403us/step - loss: 0.3719 - accuracy: 0.8396 - val_loss: 0.3794 - val_accuracy: 0.8330
# Epoch 6/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.3637 - accuracy: 0.8439 - val_loss: 0.3746 - val_accuracy: 0.8373
# Epoch 7/15
# 54400/54400 [==============================] - 22s 403us/step - loss: 0.3520 - accuracy: 0.8492 - val_loss: 0.3822 - val_accuracy: 0.8343
# Epoch 8/15
# 54400/54400 [==============================] - 22s 403us/step - loss: 0.3432 - accuracy: 0.8528 - val_loss: 0.3674 - val_accuracy: 0.8407
# Epoch 9/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.3348 - accuracy: 0.8573 - val_loss: 0.3891 - val_accuracy: 0.8290
# Epoch 10/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.3251 - accuracy: 0.8620 - val_loss: 0.3869 - val_accuracy: 0.8368
# Epoch 11/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.3154 - accuracy: 0.8668 - val_loss: 0.3742 - val_accuracy: 0.8388
# Epoch 12/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.3154 - accuracy: 0.8669 - val_loss: 0.3903 - val_accuracy: 0.8345
# Epoch 13/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.2964 - accuracy: 0.8758 - val_loss: 0.4547 - val_accuracy: 0.8256
# Epoch 14/15
# 54400/54400 [==============================] - 22s 401us/step - loss: 0.2801 - accuracy: 0.8835 - val_loss: 0.4193 - val_accuracy: 0.8389
# Epoch 15/15
# 54400/54400 [==============================] - 22s 402us/step - loss: 0.2689 - accuracy: 0.8890 - val_loss: 0.4179 - val_accuracy: 0.8378

# %%
# Get the training time
train_time = train_rt.process_time
train_time # in seconds
# Out:
# 328.931351

# %% [markdown]
# ###Test the model

# %%
test_rt = TestRuntimeCallback()
test_loss, test_acc = model.evaluate(X_test, y_test, callbacks=[test_rt])
test_loss, test_acc
# Out:
# 16000/16000 [==============================] - 5s 305us/step
# (0.42524189212918284, 0.8292499780654907)

# %%
test_time = test_rt.process_time
test_time # in seconds
# Out:
# 4.876381

# %% [markdown]
# ###Add training and test statistics to results dataframe

# %%
history_dict = history.history
history_df=pd.DataFrame(history_dict)
df = history_df.iloc[-1:].copy()
df.insert(0,'model','VGG16, 6 D') 
df['test_loss'] = test_loss 
df['test_accuracy'] = test_acc
df['train time'] = train_time     
df['test time'] = test_time   
df
# Out:
#          model  val_loss  val_accuracy  ...  test_accuracy  train time  test time
# 14  VGG16, 6 D  0.417927      0.837812  ...        0.82925  328.931351   4.876381
#
# [1 rows x 9 columns]

# %%
results_df=results_df.append(df,ignore_index=True)
results_df
# Out:
#                    model  val_loss  ...  train time  test time
# 0          DNN (1 layer)  0.588970  ...   61.349588   1.563415
# 1  DNN (2 layer dropout)  0.567190  ...   85.752367   1.706699
# 2         CNN (2 layers)  0.523904  ...   87.033493   1.846106
# 3      CNN (2 layers, D)  0.406787  ...   89.789792   1.926839
# 4        VGG16, 3 thawed  0.651987  ...  244.583603   4.925948
# 5     VGG16, 3 thawed, D  0.587627  ...  246.648250   4.863041
# 6               VGG16, 6  0.401944  ...  325.624062   4.787108
# 7             VGG16, 6 D  0.417927  ...  328.931351   4.876381
#
# [8 rows x 9 columns]

# %% [markdown]
# ### Plotting the performance

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ###ROC and AUROC

# %%
#Generate predicted probabilities for X_test, and calculate FPR and TPR 
y_pred = model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
auc_keras = auc(fpr, tpr)

# %%
#Plot ROC
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #Export results

# %%
#Export results dataframe

from google.colab import files

results_df.to_csv('PCam80k_pt.csv')
files.download('PCam80k_pt.csv')
